# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import torch
import torch.nn as nn
from torch.nn import functional as F
from transformers import Adafactor

# %%
# Hyperparameters
batch_size = 16
block_size = 64  # 32
max_iters = 10000 # 5000
eval_interval = 100
learning_rate = 1e-3
device = 'cuda' if torch.cuda.is_available() else 'cpu'
eval_iters = 200
n_embd = 64
n_head = 4
n_layer = 4
dropout = 0.0

# %%
torch.manual_seed(1337)

with open('Hafezfull.txt', 'r', encoding='utf-8') as f:
    text = f.read()

chars = sorted(list(set(text)))
vocab_size = len(chars)
# create a mapping from characters to integers
stoi = { ch:i for i,ch in enumerate(chars) }
itos = { i:ch for i,ch in enumerate(chars) }
encode = lambda s: [stoi[c] for c in s] # encoder: take a string, output a list of integers
decode = lambda l: ''.join([itos[i] for i in l]) # decoder: take a list of integers, output a string

# Train and test splits
data = torch.tensor(encode(text), dtype=torch.long)
n = int(0.85*len(data))
train_data = data[:n]
val_data = data[n:]

# %%
# data loading
def get_batch(split):
    data = train_data if split == 'train' else val_data
    ix = torch.randint(len(data) - block_size, (batch_size,))
    x = torch.stack([data[i:i+block_size] for i in ix])
    y = torch.stack([data[i+1:i+block_size+1] for i in ix])
    x, y = x.to(device), y.to(device)
    return x, y

@torch.no_grad()
def estimate_loss():
    out = {}
    model.eval()
    for split in ['train', 'val']:
        losses = torch.zeros(eval_iters)
        for k in range(eval_iters):
            X, Y = get_batch(split)
            logits, loss = model(X, Y)
            losses[k] = loss.item()
        out[split] = losses.mean()
    model.train()
    return out

class Head(nn.Module):
    """ one head of self-attention """

    def __init__(self, head_size):
        super().__init__()
        self.key = nn.Linear(n_embd, head_size, bias=False)
        self.query = nn.Linear(n_embd, head_size, bias=False)
        self.value = nn.Linear(n_embd, head_size, bias=False)
        self.register_buffer('tril', torch.tril(torch.ones(block_size, block_size)))

        self.dropout = nn.Dropout(dropout)

    def forward(self, x):
        B,T,C = x.shape
        k = self.key(x)   # (B,T,C)
        q = self.query(x) # (B,T,C)
        # compute attention scores ("affinities")
        wei = q @ k.transpose(-2,-1) * C**-0.5 # (B, T, C) @ (B, C, T) -> (B, T, T)
        wei = wei.masked_fill(self.tril[:T, :T] == 0, float('-inf')) # (B, T, T)
        wei = F.softmax(wei, dim=-1) # (B, T, T)
        wei = self.dropout(wei)
        # perform the weighted aggregation of the values
        v = self.value(x) # (B,T,C)
        out = wei @ v # (B, T, T) @ (B, T, C) -> (B, T, C)
        return out

class MultiHeadAttention(nn.Module):
    """ multiple heads of self-attention in parallel """

    def __init__(self, num_heads, head_size):
        super().__init__()
        self.heads = nn.ModuleList([Head(head_size) for _ in range(num_heads)])
        self.proj = nn.Linear(n_embd, n_embd)
        self.dropout = nn.Dropout(dropout)

    def forward(self, x):
        out = torch.cat([h(x) for h in self.heads], dim=-1)
        out = self.dropout(self.proj(out))
        return out

class FeedFoward(nn.Module):
    """ a simple linear layer followed by a non-linearity """

    def __init__(self, n_embd):
        super().__init__()
        self.net = nn.Sequential(
            nn.Linear(n_embd, 4 * n_embd),
            nn.ReLU(),
            nn.Linear(4 * n_embd, n_embd),
            nn.Dropout(dropout),
        )

    def forward(self, x):
        return self.net(x)

class Block(nn.Module):
    """ Transformer block: communication followed by computation """

    def __init__(self, n_embd, n_head):
        # n_embd: embedding dimension, n_head: the number of heads we'd like
        super().__init__()
        head_size = n_embd // n_head
        self.sa = MultiHeadAttention(n_head, head_size)
        self.ffwd = FeedFoward(n_embd)
        self.ln1 = nn.LayerNorm(n_embd)
        self.ln2 = nn.LayerNorm(n_embd)

    def forward(self, x):
        x = x + self.sa(self.ln1(x))
        x = x + self.ffwd(self.ln2(x))
        return x

class BigramLanguageModel(nn.Module):

    def __init__(self):
        super().__init__()
        # each token directly reads off the logits for the next token from a lookup table
        self.token_embedding_table = nn.Embedding(vocab_size, n_embd)
        self.position_embedding_table = nn.Embedding(block_size, n_embd)
        self.blocks = nn.Sequential(*[Block(n_embd, n_head=n_head) for _ in range(n_layer)])
        self.ln_f = nn.LayerNorm(n_embd) # final layer norm
        self.lm_head = nn.Linear(n_embd, vocab_size)

    def forward(self, idx, targets=None):
        B, T = idx.shape

        # idx and targets are both (B,T) tensor of integers
        tok_emb = self.token_embedding_table(idx) # (B,T,C)
        pos_emb = self.position_embedding_table(torch.arange(T, device=device)) # (T,C)
        x = tok_emb + pos_emb # (B,T,C)
        x = self.blocks(x) # (B,T,C)
        x = self.ln_f(x) # (B,T,C)
        logits = self.lm_head(x) # (B,T,vocab_size)

        if targets is None:
            loss = None
        else:
            B, T, C = logits.shape
            logits = logits.view(B*T, C)
            targets = targets.view(B*T)
            loss = F.cross_entropy(logits, targets)

        return logits, loss

    def generate(self, idx, max_new_tokens):
        # idx is (B, T) array of indices in the current context
        for _ in range(max_new_tokens):
            # crop idx to the last block_size tokens
            idx_cond = idx[:, -block_size:]
            # get the predictions
            logits, loss = self(idx_cond)
            # focus only on the last time step
            logits = logits[:, -1, :] # becomes (B, C)
            # apply softmax to get probabilities
            probs = F.softmax(logits, dim=-1) # (B, C)
            # sample from the distribution
            idx_next = torch.multinomial(probs, num_samples=1) # (B, 1)
            # append sampled index to the running sequence
            idx = torch.cat((idx, idx_next), dim=1) # (B, T+1)
        return idx

model = BigramLanguageModel()
m = model.to(device)
# print the number of parameters in the model
print(sum(p.numel() for p in m.parameters())/1e6, 'M parameters')

# create a PyTorch optimizer
optimizer = torch.optim.AdamW(model.parameters(), lr=learning_rate)
# optimizer = torch.optim.SGD(model.parameters(), lr=learning_rate, momentum=0.9)
# optimizer = Adafactor(model.parameters(), lr=learning_rate, scale_parameter=True,
#     relative_step=False)

for iter in range(max_iters):

    # every once in a while evaluate the loss on train and val sets
    if iter % eval_interval == 0 or iter == max_iters - 1:
        losses = estimate_loss()
        print(f"step {iter}: train loss {losses['train']:.4f}, val loss {losses['val']:.4f}")

    # sample a batch of data
    xb, yb = get_batch('train')

    # evaluate the loss
    logits, loss = model(xb, yb)
    optimizer.zero_grad(set_to_none=True)
    loss.backward()
    optimizer.step()

# generate from the model
context = torch.zeros((1, 1), dtype=torch.long, device=device)
print(decode(m.generate(context, max_new_tokens=2000)[0].tolist()))
# Out:
# 0.208294 M parameters
# step 0: train loss 3.8101, val loss 3.8034
# step 100: train loss 2.6008, val loss 2.6427
# step 200: train loss 2.5241, val loss 2.5726
# step 300: train loss 2.4573, val loss 2.5127
# step 400: train loss 2.3943, val loss 2.4490
# step 500: train loss 2.3305, val loss 2.3945
# step 600: train loss 2.2780, val loss 2.3410
# step 700: train loss 2.2411, val loss 2.3261
# step 800: train loss 2.2047, val loss 2.2822
# step 900: train loss 2.1745, val loss 2.2558
# step 1000: train loss 2.1440, val loss 2.2323
# step 1100: train loss 2.1187, val loss 2.2143
# step 1200: train loss 2.1052, val loss 2.2124
# step 1300: train loss 2.0751, val loss 2.1888
# step 1400: train loss 2.0499, val loss 2.1603
# step 1500: train loss 2.0383, val loss 2.1409
# step 1600: train loss 2.0212, val loss 2.1418
# step 1700: train loss 2.0022, val loss 2.1308
# step 1800: train loss 1.9883, val loss 2.1309
# step 1900: train loss 1.9801, val loss 2.1192
# step 2000: train loss 1.9623, val loss 2.1039
# step 2100: train loss 1.9428, val loss 2.0908
# step 2200: train loss 1.9289, val loss 2.0768
# step 2300: train loss 1.9149, val loss 2.0691
# step 2400: train loss 1.9105, val loss 2.0542
# step 2500: train loss 1.9006, val loss 2.0568
# step 2600: train loss 1.8947, val loss 2.0602
# step 2700: train loss 1.8777, val loss 2.0429
# step 2800: train loss 1.8749, val loss 2.0345
# step 2900: train loss 1.8593, val loss 2.0315
# step 3000: train loss 1.8453, val loss 2.0237
# step 3100: train loss 1.8432, val loss 2.0236
# step 3200: train loss 1.8449, val loss 2.0299
# step 3300: train loss 1.8362, val loss 2.0257
# step 3400: train loss 1.8276, val loss 2.0236
# step 3500: train loss 1.8148, val loss 2.0124
# step 3600: train loss 1.8162, val loss 2.0154
# step 3700: train loss 1.8052, val loss 2.0137
# step 3800: train loss 1.8005, val loss 2.0036
# step 3900: train loss 1.7941, val loss 2.0001
# step 4000: train loss 1.7970, val loss 2.0018
# step 4100: train loss 1.7875, val loss 1.9933
# step 4200: train loss 1.7830, val loss 2.0025
# step 4300: train loss 1.7779, val loss 2.0022
# step 4400: train loss 1.7720, val loss 2.0101
# step 4500: train loss 1.7701, val loss 2.0024
# step 4600: train loss 1.7637, val loss 2.0051
# step 4700: train loss 1.7555, val loss 1.9912
# step 4800: train loss 1.7522, val loss 1.9985
# step 4900: train loss 1.7523, val loss 1.9929
# step 5000: train loss 1.7470, val loss 2.0020
# step 5100: train loss 1.7404, val loss 1.9867
# step 5200: train loss 1.7379, val loss 1.9923
# step 5300: train loss 1.7369, val loss 1.9988
# step 5400: train loss 1.7308, val loss 1.9958
# step 5500: train loss 1.7317, val loss 1.9915
# step 5600: train loss 1.7193, val loss 1.9917
# step 5700: train loss 1.7202, val loss 1.9751
# step 5800: train loss 1.7160, val loss 1.9755
# step 5900: train loss 1.7120, val loss 1.9966
# step 6000: train loss 1.7069, val loss 1.9826
# step 6100: train loss 1.7102, val loss 2.0000
# step 6200: train loss 1.7002, val loss 1.9887
# step 6300: train loss 1.7041, val loss 1.9936
# step 6400: train loss 1.6968, val loss 1.9806
# step 6500: train loss 1.6945, val loss 1.9826
# step 6600: train loss 1.7007, val loss 1.9960
# step 6700: train loss 1.6894, val loss 1.9921
# step 6800: train loss 1.6818, val loss 1.9845
# step 6900: train loss 1.6821, val loss 1.9929
# step 7000: train loss 1.6797, val loss 1.9917
# step 7100: train loss 1.6796, val loss 1.9963
# step 7200: train loss 1.6725, val loss 1.9941
# step 7300: train loss 1.6652, val loss 1.9950
# step 7400: train loss 1.6671, val loss 1.9872
# step 7500: train loss 1.6633, val loss 1.9924
# step 7600: train loss 1.6588, val loss 1.9941
# step 7700: train loss 1.6587, val loss 1.9980
# step 7800: train loss 1.6557, val loss 1.9965
# step 7900: train loss 1.6614, val loss 2.0062
# step 8000: train loss 1.6508, val loss 1.9980
# step 8100: train loss 1.6510, val loss 1.9933
# step 8200: train loss 1.6491, val loss 1.9959
# step 8300: train loss 1.6460, val loss 2.0075
# step 8400: train loss 1.6445, val loss 1.9994
# step 8500: train loss 1.6414, val loss 2.0046
# step 8600: train loss 1.6395, val loss 1.9997
# step 8700: train loss 1.6328, val loss 1.9954
# step 8800: train loss 1.6330, val loss 2.0116
# step 8900: train loss 1.6286, val loss 2.0058
# step 9000: train loss 1.6295, val loss 2.0101
# step 9100: train loss 1.6295, val loss 2.0206
# step 9200: train loss 1.6209, val loss 1.9983
# step 9300: train loss 1.6209, val loss 2.0124
# step 9400: train loss 1.6173, val loss 1.9998
# step 9500: train loss 1.6108, val loss 2.0137
# step 9600: train loss 1.6125, val loss 2.0065
# step 9700: train loss 1.6109, val loss 2.0154
# step 9800: train loss 1.6077, val loss 2.0093
# step 9900: train loss 1.6109, val loss 2.0194
# step 9999: train loss 1.6093, val loss 2.0118
#
# سلسبا ز نظر چو تن است آن دو می‌گفت
# جان با دست نگشتند حافظ چو مسجری مشکين بخور
# بود اين حريم آييد که اين مرا برکنم
# عظم جم از شاه آمداد بازآمد از دست مگر
# دل پيش مکن انجان بود گنج مياز
# چه‌ها چو مسجد نه روح به آمد
# جوانم بهان رسيد جنگ اين قدر افشانند
# اين کارش کز کوی خمگير عارفت امروز
# چو خواهد شد از نفيست معطب دل دلشفروزی
# که ابر طرف کم دل بار ز تر عنايتم شد ساز
# چنان که به بازی از انگيخت دارد
# سحر فام سرشتی نمازم عيان نديد
# روم سايه مخمن اندر حريفان گشايد
# گر از آن قامت چو جلاب قدر جام است
# ز خواجگی حال ما و زنفت نگاه او ياری خاک
# در حريم ز مهد نگار مرا را همد دارم
# خيال معاش دردش از آن چوگان نوح دارد
# خلوت جامی ما شمال سرگران شود ازل
# غيرت گوی عمر يا رب کر صلاح و راه
# که منزل عهراق عيش نهايد نگر
# بربانی شکايت به صاحب همچو مرا طلبيق
# هر دل که ريخت می‌زدم گفت بوته بود
# از اين هخن ردش چه زر آصف است خلناب يا نر
# حافظ اين و جام می با زر بخت مکن
# مقال و جلوه مستاد را که خرابت
# ای باک سر بر ديده فسا راز او
# گو بر دل بود حرص و در آينه راه بی‌حاصلست
# چو از سرو آن ثويب پارگاه و مسکين دل است
# عبوی کاک طرف پرشهی که را آزادست
# ای شاهر که خال بر زنجيرش زمانی زنده خواهد
# اگر چه ناوک نيست دل ايشان
# همه با بر خروش طره آن پاک داری دوست
# روی و لهله ديده نيست از طلب نيست
# خاک نجست پی تو بينی که خواهد شد
# تا عمر ای مهر بود که گفت از اين
# زمان آتش نمی‌سای ميگرد نشنود
# گر چه هر نکت خويش ماه آسورينم
# حافظ از بر خاطرت دل خيال اسرار بساز
# چشم شوخش سعانی فروانيم دارم گو بهش
# که سر زلف کرد به من خوش حافظ گر من
# بنما خون که هست و گه گرگش شد ايمن کنند
# تا باد طريم چشم می می‌زندم جانم
# که حاصل کش ما بوست برون
# سر از مفلسی اندراز روزگاران شطاع آمد
# گفت بيماری و هيچ کرد لقات دوست
# که مسجد ما چه حقيقه می‌روی که آمد
# شاهال اين جهانی نگشود دل واقعين
# طبايت بگردان دگر جانبازه و راست
# قطره کند سير بت در طلب اقتراج
# به جور نمی‌کند ز حکايت‌هاست و شد آمد
# خوش بر خود هم از آن جا من ابروش
# نهاز که ترک ديدش مجرم به بزن
# چو را يک سر از آن چه پرس ناله روق
# قدر گوشش بندم نمی‌آيد
# مهر شب صنا گيرم با که شعر و باد آن چند
# شمی که کاری بسی ديده از چشم من سنگ خسکيم
# صوفی صير عاشق کريم از افسانه کنند
# خون اندربان که خواهد ببازم
# خاک بنما ما خزانه‌ای از اين دل خويش
# فکر کلک
